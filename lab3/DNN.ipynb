# %% [markdown]
# ## Generate a dataset with 10 features, 1 regression target, 150 000 rows

# %%
# !pip install faker -q
import pandas as pd
import numpy as np
from faker import Faker

from sklearn import preprocessing

faker = Faker()

def make_fake_data(num):
    fake_data = [{'pregnancies': faker.random_int(0, 5),
                  'glucose': faker.pyfloat(min_value=3, max_value=8, right_digits=1),
                  'blood_pressure':faker.random_int(60, 120),
                  'skin_thickness': faker.random_int(0, 100),
                  'insulin': faker.random_int(60, 140),
                  'age': faker.random_int(21, 80),
                  'sex': faker.boolean(),
                  'body_mass_index': faker.random_int(15, 35),
                  'pedigree_function': faker.boolean(), 
                  'blood_sugar': faker.random_int(10, 60),
                  'target':0} for x in range(num)]
    return fake_data

# Genearte fake data
num=150000
df = pd.DataFrame(make_fake_data(num))
df.head()

# Buld a relationship
for i in range(num):
    results=0
    if df.iloc[i]['sex'] == 1:
        results += 5
    if df.iloc[i]['pedigree_function'] == 1:
        results += 10
        df.at[i,'blood_pressure']=np.random.randint(60, 90)
    else:
        df.at[i,'blood_pressure']=np.random.randint(90, 120)
    if df.iloc[i]['glucose'] > 5:
        results += 10
    if df.iloc[i]['body_mass_index'] > 20:
        results += 5
    if df.iloc[i]['skin_thickness'] > 50:
        results += 5
    if df.iloc[i]['insulin'] > 100:
        df.at[i,'blood_pressure']=np.random.randint(60, 90)
        results += 10
    if df.iloc[i]['age'] > 50:
        results += 10
    if df.iloc[i]['blood_sugar'] > 6:
        results += 10
    if df.iloc[i]['blood_pressure'] < 90:
        results += 10
    if df.iloc[i]['pregnancies'] > 3:
        results += 10
    df.at[i,'target']=results
      
df.head()
# Out:
#    pregnancies  glucose  blood_pressure  skin_thickness  insulin  age    sex  \
# 0            0      6.4              91               9       67   45  False
# 1            1      6.7              97              64       61   48  False
# 2            0      4.2             108              54       65   60   True
# 3            5      5.7              60              97      123   49  False
# 4            0      3.0             103              24       90   39   True
#
#    body_mass_index  pedigree_function  blood_sugar  target
# 0               28              False           20      25
# 1               15              False           35      25
# 2               20              False           49      30
# 3               27               True           39      70
# 4               18              False           45      15

# %%
# Transform features by scaling each feature to a given range (MinMaxScaler)      
x = df.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)
df.columns = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'age', 'sex','body_mass_index', 'pedigree_function', 'blood_sugar', 'target']
df.head()
# Out:
#    pregnancies   glucose  blood_pressure  skin_thickness  insulin       age  \
# 0          0.0  0.693878        0.525424            0.09   0.0875  0.406780
# 1          0.2  0.755102        0.627119            0.64   0.0125  0.457627
# 2          0.0  0.244898        0.813559            0.54   0.0625  0.661017
# 3          1.0  0.551020        0.000000            0.97   0.7875  0.474576
# 4          0.0  0.000000        0.728814            0.24   0.3750  0.305085
#
#    sex  body_mass_index  pedigree_function  blood_sugar    target
# 0  0.0             0.65                0.0         0.20  0.200000
# 1  0.0             0.00                0.0         0.50  0.200000
# 2  1.0             0.25                0.0         0.78  0.266667
# 3  0.0             0.60                1.0         0.58  0.800000
# 4  1.0             0.15                0.0         0.70  0.066667

# %% [markdown]
# ## Design Linear Regression

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

def print_evaluate(true, predicted):  
    mse = mean_squared_error(true, predicted)
    print('MSE:', mse)
    print('__________________________________')
    
X = df[['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness', 'insulin', 'age', 'sex','body_mass_index', 'pedigree_function', 'blood_sugar']]
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

print(f'Train X = {round(X_train.shape[0]/df.shape[0]*100)}%')
print(f'Train Y = {round(y_train.shape[0]/df.shape[0]*100)}%')
print(f'Test X = {round(X_test.shape[0]/df.shape[0]*100)}%')
print(f'Test Y = {round(y_test.shape[0]/df.shape[0]*100)}%')
print('__________________________________')

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
pred = lin_reg.predict(X_test)
print_evaluate(y_test, pred)
# Out:
# Train X = 80%
# Train Y = 80%
# Test X = 20%
# Test Y = 20%
# __________________________________
# MSE: 0.006295969155164378
# __________________________________

# %% [markdown]
# ## Design 3 Dense Neural Networks (1, 5, 25 hidden layers).
# ## Prepare 3 optimizers:
# - (OPT1) SGD
# - (OPT2) RMSProp
# - (OPT3) Adam
#
#
# ## Explore the following learning rates:
# - (lr1) 0.1
# - (lr2) 0.01
# - (lr3) 0.001

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.metrics import MeanSquaredError as MSE
from tensorflow.keras.losses import MeanSquaredError

import matplotlib.pyplot as plt

def create_model(hidden_layers, optimizer, features):
    model = Sequential()
    model.add(Dense(12, activation='relu', input_shape=(32, 10)))
    for i in range(hidden_layers):
        model.add(Dense(8, activation = 'relu'))
    model.add(Dense(1, activation = 'relu'))
    model.compile(optimizer=optimizer, loss='mse', metrics=MSE())
    return model

learning_rates = [0.1, 0.01, 0.001]
optimizers = [SGD, RMSprop, Adam]
layers = [1, 5, 25]

accs = pd.DataFrame()
val_accs = pd.DataFrame()
losses = pd.DataFrame()
val_losses = pd.DataFrame()
models = []

for num_layers in layers:
    for learning_rate in learning_rates:
        for optimizer in optimizers:
            opt = '-'.join(str(optimizer).split("'")[1].split(".")[-2:])
            model = create_model(num_layers, optimizer(learning_rate=learning_rate), 10)
            history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test,y_test), batch_size=32, verbose=1,
          validation_split=0.1).history
            accs[f'{num_layers}-{learning_rate}-{opt}'] = history['mean_squared_error'] 
            val_accs[f'{num_layers}-{learning_rate}-{opt}'] = history['val_mean_squared_error'] 
            losses[f'{num_layers}-{learning_rate}-{opt}'] = history['loss'] 
            val_losses[f'{num_layers}-{learning_rate}-{opt}'] = history['val_loss'] 
            models.append(model)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 
10
# 3375/3375 [==============================] - 5s 1ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 6/10
# 3375/3375 [==============================] - 5s 1ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 7/10
# 3375/3375 [==============================] - 5s 1ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 8/10
# 3375/3375 [==============================] - 5s 1ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 9/10
# 3375/3375 [==============================] - 5s 1ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 10/10
# 3375/3375 [==============================] - 5s 1ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_90_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_90_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3371/3375 [============================>.] - ETA: 0s - loss: 0.3227 - mean_squared_error: 0.3227WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_90_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 3/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 4/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 5/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 6/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 8/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 9/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 10/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_117_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_117_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3353/3375 [============================>.] - ETA: 0s - loss: 0.3227 - mean_squared_error: 0.3227WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_117_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 2/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 3/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 5/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 6/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 7/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 8/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 9/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 10/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_144_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_144_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3370/3375 [============================>.] - ETA: 0s - loss: 0.3227 - mean_squared_error: 0.3227WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_144_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 3/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 5/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 6/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 8/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 9/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 10/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_171_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_171_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3364/3375 [============================>.] - ETA: 0s - loss: 0.0390 - mean_squared_error: 0.0390WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_171_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 3/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 5/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 6/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 8/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 9/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 10/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_198_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_198_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3364/3375 [============================>.] - ETA: 0s - loss: 0.3227 - mean_squared_error: 0.3227WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_198_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 2/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 3/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 4/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 5/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 6/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 7/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 8/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 9/10
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 10/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_225_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_225_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3360/3375 [============================>.] - ETA: 0s - loss: 0.0379 - mean_squared_error: 0.0379WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_225_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0386 - val_mean_squared_error: 0.0386
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0374 - val_mean_squared_error: 0.0374
# Epoch 3/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 4/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 5/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 6/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0376 - val_mean_squared_error: 0.0376
# Epoch 7/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 8/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 9/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 10/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_252_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_252_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3370/3375 [============================>.] - ETA: 0s - loss: 0.0495 - mean_squared_error: 0.0495WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_252_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 2/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 3/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 4/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 5/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 6/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 8/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 9/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 10/10
# 3375/3375 [==============================] - 6s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_279_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_279_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3374/3375 [============================>.] - ETA: 0s - loss: 0.3227 - mean_squared_error: 0.3227WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_279_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 2/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 3/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 4/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 5/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 6/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 7/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 8/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 9/10
# 3375/3375 [==============================] - 8s 3ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 10/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.3227 - mean_squared_error: 0.3227 - val_loss: 0.3202 - val_mean_squared_error: 0.3202
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_306_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_306_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3362/3375 [============================>.] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_306_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (32, 10).
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 2/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 3/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 4/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 5/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 6/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 7/10
# 3375/3375 [==============================] - 7s 2ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 8/10
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 9/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 10/10
# 3375/3375 [==============================] - 8s 2ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0033 - val_mean_squared_error: 0.0033

# %% [markdown]
# ## Plot learning curves for all combinations

# %%
import os

for i in accs.columns:
    x_plot = np.linspace(1, 10, 10)
    fig, axes = plt.subplots()
    axes.plot(x_plot, losses[i], label='loss')
    axes.plot(x_plot, val_losses[i], label='val_loss')
    axes.set_xlabel('epochs')
    axes.set_ylabel('losses')
    fig.legend(['train', 'test'], loc='upper right')
    fig.savefig(os.path.join(f'C:/Users/Iryna.Dosiak/results/{str(i)}.png'))
    plt.close(fig)

# %% [markdown]
# ## Collect results

# %%
results = []
for i in range(27):
    results.append([accs.columns[i], models[i].evaluate(X_test, y_test, verbose=0)[0]])
results_df = pd.DataFrame(results)
writer = pd.ExcelWriter('C:/Users/Iryna.Dosiak/results.xlsx', engine='xlsxwriter')
results_df.to_excel(writer, sheet_name='results', index=False)
writer.save()
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_3_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_6_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_9_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_12_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_15_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_18_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_21_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_24_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_27_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_34_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_41_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_48_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_55_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_62_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_69_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_76_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_83_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_90_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_117_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_144_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_171_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_198_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_225_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_252_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_279_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 32, 10) for input Tensor("dense_306_input:0", shape=(None, 32, 10), dtype=float32), but it was called on an input with incompatible shape (None, 10).
